# %%
import bm_utils

paths = ["../../preprocessing/2023_6less.npz",
         "../../preprocessing/2024_6less.npz"]
X_train, X_test, Y_train, Y_test = bm_utils.load_dataset(paths, test_size=0.1, random_state=42)
print(len(X_train), len(X_test))
# Out:
# 130683 14521

# %%
# benchmark to use
import chess
import random
random.seed(42)

# randomly picks 5 legal moves for a given board
def random_predict(board):
    legal_moves = list(board.legal_moves)
    top5_moves = []
    if len(legal_moves) <= 5:
        top5_moves = legal_moves
    else:
        top5_moves = random.sample(legal_moves, 5)
    
    return top5_moves

# %%
bm_utils.evaluate(X_test, Y_test, random_predict)
# Out:
# 100%|██████████| 14521/14521 [02:50<00:00, 85.30it/s]
# Top-1 Accuracy: 0.203
# Top-5 Accuracy: 0.764
# (0.2033606500929688, 0.7639969699056539)
